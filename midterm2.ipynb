# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

healthhiv = pd.read_csv('/content/drive/MyDrive/DATA/health_hivsenegal.csv')
healthhiv.head()

# %%
plt.figure(figsize=(15,10))
sns.violinplot(x='Year', y='Population', data=healthhiv)
labels=('Year')
plt.title('Children aged 0 to 14 Years with HIV')
# Out:
# Text(0.5, 1.0, 'Children aged 0 to 14 Years with HIV')
